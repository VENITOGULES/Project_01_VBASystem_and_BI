# %% [markdown]
# # <font color='blue'>Venito Gules de Lima</font>
#
# Sistema VBA e Power BI
#
# No Intuito de Estabelecer melhor controle da rede de barbearias, foi criado um sistema em VBA para auxiliar na governança de dados, onde existem módulos de vendas, cadastros, estoques e outros.
#
# Posteriormente à criação e parametrização do sistema, foi desenvolvido um Dashboard em PowerBI, onde fizemos desde a vinculação da Nuvem onde o sistema se encontra ao PowerBI, o processo de ETL e vinculação de tabelas no modelo Star Scheema e o desenvolvimento e design de indicadores e dashboards para auxiliar no gerenciamento da rede.

# %% [markdown]
# ### Primeira Tela
#
# Na primeira tela podemos veros indicadores gerais, segmentando Receitas, Despesas e Comissões e apresentando o Lucro (Despesas-Receitas).

# %%
from IPython.display import Image
Image("C:/Users/Venito Gules de Lima/Documents/Portfólio/Venito.github.io/images/PORTFOLIO/TELA1BI.png")

# %% [markdown]
# ### Segunda e Terceira Tela
#
# Na segunda e terceira telas, por vez, temos as aberturas de visualizações da receita, validando os dias de maiores movimentos, formas de pagamento mais usuais e uma análise mais "aberta" das despesas e receitas.

# %%
from IPython.display import Image
Image("C:/Users/Venito Gules de Lima/Documents/Portfólio/Venito.github.io/images/PORTFOLIO/TELA2BI.png")

# %%
Image("C:/Users/Venito Gules de Lima/Documents/Portfólio/Venito.github.io/images/PORTFOLIO/TELA3BI.png")

# %% [markdown]
# # Fim

# %% [markdown]
# ### Agradeço seu tempo
#
# Quaisquer dúvidas sobre os dashboards ou o projeto em si, conte comigo para esclarecimentos.
